# %% [markdown]
# 1-) Project final module 2 :
# Problématique: Pour une compagnie d'assurance,  Quels sont les facteurs qui influencent les clients  qui possèdent déjà une mutuelle santé à s'intéresser par une assurance auto.

# %%
# Libraries
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import pandas as pd
import numpy as np
import sklearn.model_selection

# %% [markdown]
# CODEBOOK:
# ![image.png](attachment:image.png)

# %%
insurance_data= pd.read_csv('C:/Users/patri/Desktop/IRONHACK/GitHub/806_Repo/Projects/Projet final module 2/train.csv')
insurance_data
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %%
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
#Rajout et tranformation de variable 
insurance_data['New_Driving_Licence']= insurance_data['Driving_License'].map({0:'Customer does not have DL',1:'Customer already has DL'})
insurance_data['New_Previously_Insured']= insurance_data['Previously_Insured'].map({0:'Customer does not have vehicule insurance',1:'Customer already has vehicule insurance'})
insurance_data['New_Vehicle_Age']= insurance_data['Vehicle_Age'].map({'< 1 Year':1,'1-2 Year':2,'> 2 Years':3})
insurance_data['New_Response']=insurance_data['Response'].map({0:'Customer is not interessed',1:'Customer is interessed'})
insurance_data
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %% [markdown]
# 2-) SPLIT DU DATASET : en 2 parties une exploratoire 80% et une autre confirmation20%

# %%
#import sklearn.cross_validation
train, test= sklearn.model_selection.train_test_split(insurance_data, train_size = 0.8, test_size=0.2)

# %%
#Valeurs nulles?
train.isnull().sum()
# Out:
# id                        0
# Gender                    0
# Age                       0
# Driving_License           0
# Region_Code               0
# Previously_Insured        0
# Vehicle_Age               0
# Vehicle_Damage            0
# Annual_Premium            0
# Policy_Sales_Channel      0
# Vintage                   0
# Response                  0
# New_Driving_Licence       0
# New_Previously_Insured    0
# New_Vehicle_Age           0
# New_Response              0
# dtype: int64

# %%
train.drop_duplicates()
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 45179    45180    Male   23                1         11.0                   0
# 52765    52766  Female   52                1          8.0                   1
# 173535  173536    Male   39                1         28.0                   0
# 310483  310484    Male   47                1         46.0                   1
# 113903  113904  Female   25                1         29.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 168420  168421    Male   25                1         16.0                   1
# 287313  287314  Female   29                1         11.0                   1
# 231136  231137    Male   42                1         27.0                   0
# 247711  247712  Female   23                1         11.0                   1
# 135036  135037    Male   69                1         50.0                   0
#
# ...

# %%
train.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  304887.000000  304887.000000    304887.000000  304887.000000
# mean   190383.296694      38.810162         0.997871      26.399279
# std    110039.480452      15.510205         0.046088      13.226418
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95013.500000      25.000000         1.000000      15.000000
# 50%    190211.000000      36.000000         1.000000      28.000000
# 75%    285723.500000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       304887.000000   304887.000000         304887.000000
# mean             0.458114    30567.829707            112.087629
# std              0.498243    17221.358820             54.203181
# min              0.000000     2630.000000              1.000000
# ...

# %% [markdown]
# # Analyse univariée des variables numériques

# %%
#Distribution normal?
plt.hist(train['Age'])
# nous remarquons que la variable Age est une long tailed on en déduit qu'il y a plus de
# Out:
# (array([102471.,  35258.,  29963.,  38286.,  37419.,  21224.,  17796.,
#          11815.,   9072.,   1583.]),
#  array([20. , 26.5, 33. , 39.5, 46. , 52.5, 59. , 65.5, 72. , 78.5, 85. ]),
#  <a list of 10 Patch objects>)

# %%
n, bins, patches = plt.hist(train['Age'], 50, density=True, facecolor='g', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of Age')
plt.text(60, .025, r'$\mu=38.821800,\ \sigma=15.505742$')
plt.axis([20, 85, 0, 0.03])
plt.grid(True)
plt.show()

# %%
#Checking outliers
plt.boxplot(train['Age'])
# nous ne trouvons pas de outliers
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x253d639b148>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x253d638c408>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x253ce432608>],
#  'medians': [<matplotlib.lines.Line2D at 0x253d639d108>],
#  'fliers': [<matplotlib.lines.Line2D at 0x253d639de48>],
#  'means': []}

# %%
# Prime annuelle
plt.hist(train['Annual_Premium'],bins=20)
# Out:
# (array([1.27025e+05, 1.64209e+05, 1.20880e+04, 1.18500e+03, 1.99000e+02,
#         5.00000e+01, 3.30000e+01, 1.60000e+01, 1.80000e+01, 8.00000e+00,
#         1.30000e+01, 1.40000e+01, 1.30000e+01, 4.00000e+00, 3.00000e+00,
#         0.00000e+00, 1.00000e+00, 3.00000e+00, 2.00000e+00, 3.00000e+00]),
#  array([  2630.  ,  29506.75,  56383.5 ,  83260.25, 110137.  , 137013.75,
#         163890.5 , 190767.25, 217644.  , 244520.75, 271397.5 , 298274.25,
#         325151.  , 352027.75, 378904.5 , 405781.25, 432658.  , 459534.75,
#         486411.5 , 513288.25, 540165.  ]),
#  <a list of 20 Patch objects>)

# %%
n, bins, patches = plt.hist(train['Age'], 50, density=True, facecolor='g', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of Annual Premium')
plt.text(60, .025, r'$\mu=30559.479656,\ \sigma=17202.491037$')
plt.axis([2630, 540165, 0, 0.03])
plt.grid(True)
plt.show()

# %%
#checking outlier
plt.boxplot(train['Annual_Premium'])
#on constate qu'il y a effectivement des outliers pour cette variables cela pourrait s'expliquer par le fait que:
# les primes diffèrent d'une client à un autre cela dépend des garanties soucrites.
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x253d6615088>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x253d65a7c08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x253d661d708>],
#  'medians': [<matplotlib.lines.Line2D at 0x253d6605748>],
#  'fliers': [<matplotlib.lines.Line2D at 0x253d6606cc8>],
#  'means': []}

# %%
#plt.bar(,bins=20)
train['Vintage'].value_counts().plot.bar()

# %%
#la variable vintage ne contient pas de outlier
plt.boxplot(train['Vintage'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x253d6c4b648>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x253d6c67688>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x253d6c58a88>],
#  'medians': [<matplotlib.lines.Line2D at 0x253d6c6b648>],
#  'fliers': [<matplotlib.lines.Line2D at 0x253d6c6be48>],
#  'means': []}

# %% [markdown]
# #Analyse univariée variables catégorielles

# %%
train['Gender'].value_counts(sort=False).plot.pie(autopct='%1.1f%%')

# %%
my_tab_Gender = pd.crosstab(index = train['Gender'],  # Make a crosstab
                              columns="count_Gender") # Name the count column
my_tab_Gender.plot.pie(autopct='%1.1f%%',subplots=True)

#my_tab.plot.bar()
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000253D6B1AB88>],
#       dtype=object)

# %%
train['New_Driving_Licence'].value_counts(sort=False).plot.pie(autopct='%1.1f%%')

# %%
train['New_Previously_Insured'].value_counts(sort=False).plot.pie(autopct='%1.1f%%')

# %%
train['Vehicle_Damage'].value_counts(sort=False).plot.pie(autopct='%1.1f%%')

# %%
train['Policy_Sales_Channel'].value_counts(sort=False).plot.pie(autopct='%1.1f%%')

# %%
my_tab_Policy_Sales_Channel = pd.crosstab(index = train['Policy_Sales_Channel'],  # Make a crosstab
                              columns="count_Policy_Sales_Channel") # Name the count column
my_tab_Policy_Sales_Channel.plot.pie(autopct='%1.1f%%',subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000253D717AE08>],
#       dtype=object)

# %% [markdown]
# # Analyse bivariée matrice cible= Response

# %%
# correlation entre la variable Age et la variable cible Response
scipy.stats.pointbiserialr(train['Age'],train['Response'])
#On en déduit que la relation est faible entre l'age et
# Out:
# PointbiserialrResult(correlation=0.11176238717957558, pvalue=0.0)

# %%
train['Age'].corr(train['Response'], method="pearson")
# Out:
# 0.11176238717957482

# %%
#relation entre la variable Age et la variable cible
train.boxplot(column="Age",        # Column to plot
                 by= "Response",         # Column to split upon
                 figsize= (8,8))        # Figure size

# %%
# correlation entre la variable Annual prime et la variable cible Response
train['Annual_Premium'].corr(train['Response'], method="pearson")
#On en déduit que la relation est faible entre la prime annuelle et la variable cible
# Out:
# 0.02276875143779328

# %%
train.boxplot(column="Annual_Premium",        # Column to plot
                 by= "Response",         # Column to split upon
                 figsize= (8,8))        # Figure size

# %%
# correlation entre la variable Nombre d'années et la variable cible Response
train['Vintage'].corr(train['Response'], method="pearson")
#On en déduit que la relation est negative entre le nombre d'année et la variable cible
# Out:
# -0.00029833798991893315

# %%
train.boxplot(column="Vintage",        # Column to plot
                 by= "Response",         # Column to split upon
                 figsize= (8,8))        # Figure size

# %%
# correlation entre la variable Nombre d'années et la variable cible Response
train['New_Vehicle_Age'].corr(train['Response'], method="pearson")
#On en déduit que la relation est negative entre le nombre d'année et la variable cible
# Out:
# 0.22080485343988968

# %%
train.boxplot(column="New_Vehicle_Age",        # Column to plot
                 by= "Response",         # Column to split upon
                 figsize= (8,8))        # Figure size

# %%
#corrélation entre le genre et la variable cible
def cramers_V(var1,var2) :
  crosstab =np.array(pd.crosstab(var1,var2, rownames=None, colnames=None)) # Cross table building
  stat = scipy.stats.chi2_contingency(crosstab)[0] # Keeping of the test statistic of the Chi2 test
  obs = np.sum(crosstab) # Number of observations
  mini = min(crosstab.shape)-1 # Take the minimum value between the columns and the rows of the cross table
  return (stat/(obs*mini))
cramers_V(train['Gender'],train['New_Response'])
# Out:
# 0.002764214233315414

# %%
grouped_Gender_New_Response = train.groupby(['Gender','New_Response'])
grouped_Gender_New_Response.size()
# Out:
# Gender  New_Response
# Female  Customer is interessed         14539
#         Customer is not interessed    125452
# Male    Customer is interessed         22832
#         Customer is not interessed    142064
# dtype: int64

# %%
Gender_New_Response_table = pd.crosstab(index=train["New_Response"], 
                          columns=train["Gender"])

Gender_New_Response_table
# Out:
# Gender                      Female    Male
# New_Response
# Customer is interessed       14539   22832
# Customer is not interessed  125452  142064

# %%
Gender_New_Response_table.plot(kind="bar", 
                 figsize=(8,8),
                 stacked=True)

# %%
#corrélation entre le genre et la variable cible
cramers_V(train['New_Driving_Licence'],train['New_Response'])
# Out:
# 9.557095305031645e-05

# %%
New_Driving_Licence_Response_table = pd.crosstab(index=train["New_Response"], 
                          columns=train["New_Driving_Licence"])
New_Driving_Licence_Response_table
# Out:
# New_Driving_Licence         Customer already has DL  Customer does not have DL
# New_Response
# Customer is interessed                        37337                         34
# Customer is not interessed                   266901                        615

# %%
New_Driving_Licence_Response_table.plot(kind="bar", 
                 figsize=(8,8),
                 stacked=True)

# %%
# Corrélation entre le fait d'avoir une assurance auto et la variable cible
cramers_V(train['New_Previously_Insured'],train['New_Response'])
# Out:
# 0.11640244818085016

# %%
New_Previously_Insured_Response_table = pd.crosstab(index=train["New_Response"], 
                          columns=train["New_Previously_Insured"])
New_Previously_Insured_Response_table
# Out:
# New_Previously_Insured      Customer already has vehicule insurance  \
# New_Response
# Customer is interessed                                          123
# Customer is not interessed                                   139550
#
# New_Previously_Insured      Customer does not have vehicule insurance
# New_Response
# Customer is interessed                                          37248
# Customer is not interessed                                     127966

# %%
New_Previously_Insured_Response_table.plot(kind="bar", 
                 figsize=(8,8),
                 stacked=True)

# %%
#corrélation entre le genre et la variable cible
cramers_V(train['Vehicle_Damage'],train['New_Response'])
# Out:
# 0.12557476257356945

# %%
Vehicle_Damage_Response_table = pd.crosstab(index=train["New_Response"], 
                          columns=train["Vehicle_Damage"])
Vehicle_Damage_Response_table
# Out:
# Vehicle_Damage                  No     Yes
# New_Response
# Customer is interessed         787   36584
# Customer is not interessed  150164  117352

# %%
Vehicle_Damage_Response_table.plot(kind="bar", 
                 figsize=(8,8),
                 stacked=True)

# %%
# existe t'il une relation entre l'age et le montant de la prime
#le test de corrélation de Pearson
#H0= les personnes de plus de 50 ont une prime plus élevée
#train['Age'].corr(train['Annual_Premium'])

# %%
#train.plot.scatter(x=train['Age'], y=train['Annual_Premium'], alpha=0.2, grid=True)
#sns.lmplot(x='Annual_Premium', y='Age',  data=train)

# %%
#train_to_tableau= train.to_csv('C:/Users/patri/Desktop/IRONHACK/GitHub/806_Repo/Projects/Projet final module 2/train_to_tableau.csv')

# %%
#La variable Response ne forte corrélation avec LSTAT et RM. Cependant il ne faut pas négliger les autres attributs comme CRIM,ZN,INDUS… car leur corrélation sont pas proches de 0. Il faut savoir que lorsqu’on fait une régression linéaire on pose certaines hypothèses notamment la Non-colinéarité des variables explicatives (une variable explicative ne doit pas pouvoir s’écrire comme combinaison linéaire des autres).

#TAX et RAD ont une corrélation de 0.9; NOX et  DIS et AGE ont une corrélation de 0.7 ; DIS et INDUS ont une corrélation de 0.7.
#Après une analyse minutieuse nous choisissons : LSAT, RM,TAX,PTRATIO

# %%
matrice_corr = train.corr()
sns.heatmap(data=matrice_corr, annot=True)

# %% [markdown]
# #Regression linéaire

# %%
#choix des variables explicatives nous choisiront les variables qui sont proches
#de 0 càd des variables qui ont une corrélation positives.
#on utilise seulement 4 variables explicatives
#X=pd.DataFrame(np.c_[train['Age'],train['Annual_Premium'],train['New_Vehicle_Age'],train['Driving_License'],train['Previously_Insured']], columns = ['Age','Drving_License','New_vehicule_Age','Drving_License','Previously_Insured'])
#Y = train['Response']

# %%
#X_train, X_test, Y_train, Y_test= sklearn.model_selection.train_test_split(X , Y, test_size=0.2, random_state=5)
#X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
#print(X_train.shape)
#print(X_test.shape)
#print(Y_train.shape)
#print(Y_test.shape)

# %%
#from sklearn.linear_model import LinearRegression
#from sklearn.metrics import mean_squared_error
#lmodellineaire = LinearRegression()
#lmodellineaire.fit(X_train, Y_train)

# %%
#X_train.plot.bar()

# %% [markdown]
#  #TEST Hypothèse

# %%
#H0 : les variables Previously insured et Response sont indépendantes avec un intervale de confiance de à 95%
import researchpy as rp
rp.summary_cat(train[["New_Previously_Insured", "New_Response"]])
# Out:
#                  Variable                                    Outcome   Count  \
# 0  New_Previously_Insured  Customer does not have vehicule insurance  165214
# 1                            Customer already has vehicule insurance  139673
# 2            New_Response                 Customer is not interessed  267516
# 3                                             Customer is interessed   37371
#
#    Percent
# 0    54.19
# 1    45.81
# 2    87.74
# 3    12.26

# %%
crosstab_Previously_Insured_response = pd.crosstab(train["New_Previously_Insured"],train["New_Response"])

crosstab_Previously_Insured_response
# Out:
# New_Response                               Customer is interessed  \
# New_Previously_Insured
# Customer already has vehicule insurance                       123
# Customer does not have vehicule insurance                   37248
#
# New_Response                               Customer is not interessed
# New_Previously_Insured
# Customer already has vehicule insurance                        139550
# Customer does not have vehicule insurance                      127966

# %%
scipy.stats.chi2_contingency(crosstab_Previously_Insured_response)
# Out:
# (35489.59321851486,
#  0.0,
#  1,
#  array([[ 17120.17791182, 122552.82208818],
#         [ 20250.82208818, 144963.17791182]]))

# %%
crosstab, test_results, expected = rp.crosstab(train["New_Previously_Insured"],train["New_Response"],
                                               test= "chi-square",
                                               expected_freqs= True,
                                               prop= "cell")
crosstab
# Out:
#                                                     New_Response  \
# New_Response                              Customer is interessed
# New_Previously_Insured
# Customer already has vehicule insurance                     0.04
# Customer does not have vehicule insurance                  12.22
# All                                                        12.26
#
#
# New_Response                              Customer is not interessed     All
# New_Previously_Insured
# Customer already has vehicule insurance                        45.77   45.81
# Customer does not have vehicule insurance                      41.97   54.19
# All                                                            87.74  100.00

# %%
#Méthode notebook JM
#échantillonage des variables 
independance_test_Previously_Insured= train[["New_Previously_Insured",'New_Response']].sample(n=10000, random_state=1)
independance_test_Previously_Insured
# tableau de contingence après échantillonage
independance_test_Previously_Insured_tab = pd.crosstab(independance_test_Previously_Insured['New_Previously_Insured'],independance_test_Previously_Insured['New_Response'], margins = True)
independance_test_Previously_Insured_tab.columns=['Customer is interessed','Customer is not interessed','Columns1']
independance_test_Previously_Insured_tab.index=['Customer already has vehicule insurance','Customer does not have vehicule insurance','rows1']
independance_test_Previously_Insured_tab
#variable observé
independance_test_Previously_Insured_observed = independance_test_Previously_Insured_tab.iloc[0:2,0:2]
independance_test_Previously_Insured_observed

#expected variable
independance_test_Previously_Insured_expected =  np.outer(independance_test_Previously_Insured_tab["Columns1"][0:2],
                     independance_test_Previously_Insured_tab.loc["rows1"][0:2]) / 10000
independance_test_Previously_Insured_expected
independance_test_Previously_Insured_expected = pd.DataFrame(independance_test_Previously_Insured_expected)

independance_test_Previously_Insured_expected.columns = ['Customer is interessed','Customer is not interessed']
independance_test_Previously_Insured_expected.index = ['Customer already has vehicule insurance','Customer does not have vehicule insurance']
independance_test_Previously_Insured_expected
#chi_square
independance_test_Previously_Insured_chi_squared_stat = (((independance_test_Previously_Insured_observed-independance_test_Previously_Insured_expected)**2)/independance_test_Previously_Insured_expected).sum().sum()
independance_test_Previously_Insured_chi_squared_stat
#critical value
independance_test_Previously_Insured_chi_crit = scipy.stats.chi2.ppf(q = 0.95, # Find the critical value for 95% confidence*
                      df = 1)   # *
independance_test_Previously_Insured_chi_crit

#p-value
independance_test_Previously_Insured_p_value = 1 - scipy.stats.chi2.cdf(x=independance_test_Previously_Insured_chi_squared_stat,  # Find the p-value
                             df=1)
independance_test_Previously_Insured_p_value
# Out:
# 0.0

# %%
#Méthode RP research
crosstab_Previously_Insured, test_results_Previously_Insured, expected_Previously_Insured = rp.crosstab(independance_test_Previously_Insured['New_Previously_Insured'],independance_test_Previously_Insured['New_Response'],
                                               test= "chi-square",
                                               expected_freqs= True,
                                               prop= "cell")
test_results_Previously_Insured
# Out:
#                 Chi-square test    results
# 0  Pearson Chi-square ( 1.0) =   1201.6842
# 1                    p-value =      0.0000
# 2               Cramer's phi =      0.3467

# %%
#confirmation sur la population test
#Méthode notebook JM
#échantillonage des variables 
independance_test_Previously_Insured2= test[["New_Previously_Insured",'New_Response']].sample(n=10000, random_state=1)
independance_test_Previously_Insured2
# tableau de contingence après échantillonage
independance_test_Previously_Insured_tab2 = pd.crosstab(independance_test_Previously_Insured2['New_Previously_Insured'],independance_test_Previously_Insured2['New_Response'], margins = True)
independance_test_Previously_Insured_tab2.columns=['Customer is interessed','Customer is not interessed','Columns1']
independance_test_Previously_Insured_tab2.index=['Customer already has vehicule insurance','Customer does not have vehicule insurance','rows1']
independance_test_Previously_Insured_tab2
#variable observé
independance_test_Previously_Insured_observed2 = independance_test_Previously_Insured_tab2.iloc[0:2,0:2]
independance_test_Previously_Insured_observed2

#expected variable
independance_test_Previously_Insured_expected2 =  np.outer(independance_test_Previously_Insured_tab2["Columns1"][0:2],
                     independance_test_Previously_Insured_tab2.loc["rows1"][0:2]) / 10000
independance_test_Previously_Insured_expected2
independance_test_Previously_Insured_expected2 = pd.DataFrame(independance_test_Previously_Insured_expected2)

independance_test_Previously_Insured_expected2.columns = ['Customer is interessed','Customer is not interessed']
independance_test_Previously_Insured_expected2.index = ['Customer already has vehicule insurance','Customer does not have vehicule insurance']
independance_test_Previously_Insured_expected2
#chi_square
independance_test_Previously_Insured_chi_squared_stat2 = (((independance_test_Previously_Insured_observed2-independance_test_Previously_Insured_expected2)**2)/independance_test_Previously_Insured_expected2).sum().sum()
independance_test_Previously_Insured_chi_squared_stat2
#critical value
independance_test_Previously_Insured_chi_crit2 = scipy.stats.chi2.ppf(q = 0.95, # Find the critical value for 95% confidence*
                     df = 1)   # *
independance_test_Previously_Insured_chi_crit2

#p-value
independance_test_Previously_Insured_p_value2 = 1 - scipy.stats.chi2.cdf(x=independance_test_Previously_Insured_chi_squared_stat2,  # Find the p-value
                            df=1)
independance_test_Previously_Insured_p_value2
# Out:
# 0.0

# %%
# Out:
# New_Response                               Customer is interessed  \
# New_Previously_Insured
# Customer already has vehicule insurance                        36
# Customer does not have vehicule insurance                    9394
#
# New_Response                               Customer is not interessed
# New_Previously_Insured
# Customer already has vehicule insurance                         34741
# Customer does not have vehicule insurance                       32051

# %%
# independance response vs vehicle damage
#Méthode notebook JM
#échantillonage des variables 
independance_test_Vehicle_Damage= train[["Vehicle_Damage",'New_Response']].sample(n=10000, random_state=1)
independance_test_Vehicle_Damage
# tableau de contingence après échantillonage
independance_test_Vehicle_Damage_tab = pd.crosstab(independance_test_Vehicle_Damage['Vehicle_Damage'],independance_test_Vehicle_Damage['New_Response'], margins = True)
independance_test_Vehicle_Damage_tab.columns=['Customer is interessed','Customer is not interessed','Columns1']
independance_test_Vehicle_Damage_tab.index=['YES','NO','rows1']
independance_test_Vehicle_Damage_tab
#variable observé
independance_test_Vehicle_Damage_observed = independance_test_Vehicle_Damage_tab.iloc[0:2,0:2]
independance_test_Vehicle_Damage_observed

#expected variable
independance_test_Vehicle_Damage_expected =  np.outer(independance_test_Vehicle_Damage_tab["Columns1"][0:2],
                     independance_test_Vehicle_Damage_tab.loc["rows1"][0:2]) / 10000
independance_test_Vehicle_Damage_expected
independance_test_Vehicle_Damage_expected = pd.DataFrame(independance_test_Vehicle_Damage_expected)

independance_test_Vehicle_Damage_expected.columns = ['Customer is interessed','Customer is not interessed']
independance_test_Vehicle_Damage_expected.index =['YES','NO']
independance_test_Vehicle_Damage_expected
#chi_square
independance_test_Vehicle_Damage_chi_squared_stat = (((independance_test_Vehicle_Damage_observed-independance_test_Vehicle_Damage_expected)**2)/independance_test_Vehicle_Damage_expected).sum().sum()
independance_test_Vehicle_Damage_chi_squared_stat
#critical value
independance_test_Vehicle_Damage_chi_crit = scipy.stats.chi2.ppf(q = 0.95, # Find the critical value for 95% confidence*
                     df = 1)   # *
independance_test_Vehicle_Damage_chi_crit

#p-value
independance_test_Vehicle_Damage_p_value = 1 - scipy.stats.chi2.cdf(x=independance_test_Vehicle_Damage_chi_squared_stat,  # Find the p-value
                           df=1)
independance_test_Vehicle_Damage_p_value
# Out:
# 0.0

# %%
crosstab_Vehicle_Damage, test_results_Vehicle_Damage, expected_Vehicle_Damage = rp.crosstab(independance_test_Vehicle_Damage['Vehicle_Damage'],independance_test_Vehicle_Damage['New_Response'],
                                               test= "chi-square",
                                               expected_freqs= True,
                                               prop= "cell")
test_results_Vehicle_Damage
# Out:
#                 Chi-square test    results
# 0  Pearson Chi-square ( 1.0) =   1320.6510
# 1                    p-value =      0.0000
# 2               Cramer's phi =      0.3634

# %%
#confirmation sur la population test
independance_test_Vehicle_Damage2= test[["Vehicle_Damage",'New_Response']].sample(n=10000, random_state=1)
independance_test_Vehicle_Damage2
# tableau de contingence après échantillonage
independance_test_Vehicle_Damage_tab2 = pd.crosstab(independance_test_Vehicle_Damage2['Vehicle_Damage'],independance_test_Vehicle_Damage2['New_Response'], margins = True)
independance_test_Vehicle_Damage_tab2.columns=['Customer is interessed','Customer is not interessed','Columns1']
independance_test_Vehicle_Damage_tab2.index=['YES','NO','rows1']
independance_test_Vehicle_Damage_tab2
#variable observé
independance_test_Vehicle_Damage_observed2 = independance_test_Vehicle_Damage_tab2.iloc[0:2,0:2]
independance_test_Vehicle_Damage_observed2

#expected variable
independance_test_Vehicle_Damage_expected2 =  np.outer(independance_test_Vehicle_Damage_tab2["Columns1"][0:2],
                     independance_test_Vehicle_Damage_tab2.loc["rows1"][0:2]) / 10000
independance_test_Vehicle_Damage_expected2
independance_test_Vehicle_Damage_expected2 = pd.DataFrame(independance_test_Vehicle_Damage_expected2)

independance_test_Vehicle_Damage_expected2.columns = ['Customer is interessed','Customer is not interessed']
independance_test_Vehicle_Damage_expected2.index =['YES','NO']
independance_test_Vehicle_Damage_expected2
#chi_square
independance_test_Vehicle_Damage_chi_squared_stat2 = (((independance_test_Vehicle_Damage_observed2-independance_test_Vehicle_Damage_expected2)**2)/independance_test_Vehicle_Damage_expected2).sum().sum()
independance_test_Vehicle_Damage_chi_squared_stat2
#critical value
independance_test_Vehicle_Damage_chi_crit2 = scipy.stats.chi2.ppf(q = 0.95, # Find the critical value for 95% confidence*
                     df = 1)   # *
independance_test_Vehicle_Damage_chi_crit2

#p-value
independance_test_Vehicle_Damage_p_value2 = 1 - scipy.stats.chi2.cdf(x=independance_test_Vehicle_Damage_chi_squared_stat2,  # Find the p-value
                           df=1)
independance_test_Vehicle_Damage_p_value2
# Out:
# 0.0

# %%
# Out:
# (8877.435890893938,
#  0.0,
#  1,
#  array([[ 4302.52564876, 30474.47435124],
#         [ 5127.47435124, 36317.52564876]]))

# %%
crosstabtest, test_test_results, test_test_expected = rp.crosstab(test["New_Previously_Insured"],test["New_Response"],
                                               test= "chi-square",
                                               expected_freqs= True,
                                               prop= "cell")
crosstabtest
# Out:
#                                                     New_Response  \
# New_Response                              Customer is interessed
# New_Previously_Insured
# Customer already has vehicule insurance                     0.05
# Customer does not have vehicule insurance                  12.32
# All                                                        12.37
#
#
# New_Response                              Customer is not interessed     All
# New_Previously_Insured
# Customer already has vehicule insurance                        45.58   45.63
# Customer does not have vehicule insurance                      42.05   54.37
# All                                                            87.63  100.00

# %%
test_test_results
# Out:
#                 Chi-square test    results
# 0  Pearson Chi-square ( 1.0) =   8879.5170
# 1                    p-value =      0.0000
# 2               Cramer's phi =      0.3413

# %%
test_test_expected
# Out:
#                                                     New_Response  \
# New_Response                              Customer is interessed
# New_Previously_Insured
# Customer already has vehicule insurance              4302.525649
# Customer does not have vehicule insurance            5127.474351
#
#
# New_Response                              Customer is not interessed
# New_Previously_Insured
# Customer already has vehicule insurance                 30474.474351
# Customer does not have vehicule insurance               36317.525649

# %%
#H0: les variables vehicle Damage et response sont indépendante
crosstab1, test_results1, test_expected1 = rp.crosstab(test["Vehicle_Damage"],test["New_Response"],
                                               test= "chi-square",
                                               expected_freqs= True,
                                               prop= "cell")
test_results1
# Out:
#                 Chi-square test    results
# 0  Pearson Chi-square ( 1.0) =   9585.1415
# 1                    p-value =      0.0000
# 2               Cramer's phi =      0.3546

# %%
#H0: les variables vehicle Gender et response sont indépendante
crosstab2, test_results2, test_expected2 = rp.crosstab(test["Gender"],test["New_Response"],
                                               test= "chi-square",
                                               expected_freqs= True,
                                               prop= "cell")
test_results2
# Out:
#                 Chi-square test   results
# 0  Pearson Chi-square ( 1.0) =   233.0017
# 1                    p-value =     0.0000
# 2               Cramer's phi =     0.0553

# %%
#H0: les variables vehicle Driving_Licence et response sont indépendante
crosstab3, test_results3, test_expected3 = rp.crosstab(test["New_Driving_Licence"],test["New_Response"],
                                               test= "chi-square",
                                               expected_freqs= True,
                                               prop= "cell")
test_results3
# Out:
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    8.7530
# 1                    p-value =    0.0031
# 2               Cramer's phi =    0.0107

# %%
#rp.crosstab(train["New_Previously_Insured"],train["New_Response"],
                                               #test= "chi-square",
                                               #expected_freqs= True,
                                               #prop= "cell"), voters.party, margins = True)

#rp.crosstab(train["New_Previously_Insured"],train["New_Response"],
                                               #test= "chi-square",
                                               #expected_freqs= True,
                                               #prop= "cell")
# Out:
#                                            Customer is interessed  \
# Customer already has vehicule insurance                         3
# Customer does not have vehicule insurance                    1216
# rows1                                                        1219
#
#                                            Customer is not interessed  \
# Customer already has vehicule insurance                          4573
# Customer does not have vehicule insurance                        4208
# rows1                                                            8781
#
#                                            Columns1
# Customer already has vehicule insurance        4576
# Customer does not have vehicule insurance      5424
# rows1                                         10000

# %%
# Out:
#                                            Customer is interessed  \
# Customer already has vehicule insurance                         3
# Customer does not have vehicule insurance                    1216
#
#                                            Customer is not interessed
# Customer already has vehicule insurance                          4573
# Customer does not have vehicule insurance                        4208

# %%
# Out:
#                                            Customer is interessed  \
# Customer already has vehicule insurance                  557.8144
# Customer does not have vehicule insurance                661.1856
#
#                                            Customer is not interessed
# Customer already has vehicule insurance                     4018.1856
# Customer does not have vehicule insurance                   4762.8144

# %%
# Out:
# 1158.6227974762678

# %%
# Out:
# 0.0

# %%
# Out:
#                 Chi-square test    results
# 0  Pearson Chi-square ( 1.0) =   1158.6228
# 1                    p-value =      0.0000
# 2               Cramer's phi =      0.3404
